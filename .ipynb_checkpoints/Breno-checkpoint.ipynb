# %% [markdown]
# # Trabalho Prático I
# ###### Aluno: Breno de Sousa Matos
# ###### Matrícula: 2017086007

# %%
import io
import sqlite3
import pandas as pd

# %% [markdown]
# Iniciando Conexão

# %%
conn = sqlite3.connect('tp1.bd')
cursor = conn.cursor()

# %% [markdown]
# Lendo os dados necessários

# %%
with open("despesas_publicas_tp1.sql", "r", encoding = "latin-1") as f:
    sql = f.read()
    
cursor.executescript(sql)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-9-9f3008e5d14b> in <module>
#       2     sql = f.read()
#       3
# ----> 4 cursor.executescript(sql)
#       5
#
# OperationalError: table [ORGAO] already exists

# %% [markdown]
# ## 1. Comandos SQL

# %% [markdown]
# Meu número de matrícula é $\textbf{2017086007}$. Logo, devo realizar as consultas:
#
#  1,9,7,2,3 e 8

# %% [markdown]
# ### 1.1 Consulta 1

# %%
# Liste todos os códigos e nomes de subfunções da função que possui o maior número de subfuncoes.
query = ''
df = pd.read_sql_query(query,conn)
df
# Out:
#    COD_SUBFUNCAO               NOME_SUBFUNCAO
# 0            125  Normatização e fiscalização
# 1            126     Tecnologia da informação
# 2            131           Comunicação social
# 3            244      Assistência comunitária
# 4            306       Alimentação e nutrição
# 5            365            Educação infantil
# 6            511      Saneamento básico rural

# %% [markdown]
# ### 1.2 Consulta 9

# %%
# Liste todas as despesas públicas (código da despesa, mês e ano da despesa, modalidade, valor) 
# em que o órgão responsável é aquele que possui o maior número de órgãos subordinados.

# %% [markdown]
# ### 1.3 Consulta 7

# %%
# Liste os órgãos governamentais e a quantidade de programas de governo distintos envolvidos 
# nas despesas públicas desses órgãos.
# Nesta consulta, desconsidere valores de despesa negativos ou iguais a zero no perı́odo.

# %% [markdown]
# ### 1.4 Consulta 2

# %%
# Liste o valor total de despesas públicas por função (nome) e subfunção (nome), apenas
# nos casos em que esse valor total excedeu 200 mil reais.
query = 'SELECT * from DESPESA_PUBLICA'
pd.read_sql_query(query,conn)
# Out:
#       COD_DESPESA  COD_ORGAO  COD_PROGRAMA_GOVERNO  COD_DETALHAMENTO  \
# 0               0      20000                    24                 8
# 1               1      20000                    24                10
# 2               2      20000                    24                10
# 3               3      20000                    24                11
# 4               4      20000                    24                11
# 5               5      20000                    24                11
# 6               6      20000                    24                11
# 7               7      20000                    24                11
# 8               8      20000                    29                 4
# 9               9      20000                    29                 4
# 10             10      22000                    22                35
# 11             11      22000                    22                35
# 12             12      22000                    22                35
# 13             13      22000                    22                35
# 14             14      22000                    22                35
# 15             15      22000                    22                35
# 16             16      22000                    22                35
# 17             17      22000                    22                35
# 18             18      22000                    22                35
# 19             19      22000                    22                35
# 20             20      22000                    24                10
# 21             21      22000                    24                10
# 22             22      22000                    24                10
# 23             23      22000                    24                10
# 24             24      22000                    24                10
# 25             25      22000                    24                10
# 26             26      22000                    24                10
# 27             27      22000                    24                10
# 28             28      22000                    24                10
# 29             29      22000                    24                10
# ...           ...        ...                   ...               ...
# 1097         1097      55000                    24                13
# 1098         1098      55000                    24                13
# 1099         1099      55000                    24                13
# 1100         1100      55000                    24                13
APLICACOES DIRETAS - OPER.INTRA-ORCAMENTARIAS            0.0
# 27                              Reserva de Contingência            0.0
# 28                              Reserva de Contingência         8215.7
# 29                              Reserva de Contingência            0.0
# ...                                                 ...            ...
# 1097     Transferências a Estados e ao Distrito Federal            0.0
# 1098     Transferências a Estados e ao Distrito Federal            0.0
# 1099     Transferências a Estados e ao Distrito Federal            0.0
# 1100     Transferências a Estados e ao Distrito Federal            0.0
# 1101     Transferências a Estados e ao Distrito Federal            0.0
# 1102     Transferências a Estados e ao Distrito Federal            0.0
# 1103     Transferências a Estados e ao Distrito Federal            0.0
# 1104     Transferências a Estados e ao Distrito Federal            0.0
# 1105  Transferências a Instituições Privadas sem Fin...            0.0
# 1106  Transferências a Instituições Privadas sem Fin...            0.0
# 1107  Transferências a Instituições Privadas sem Fin...            0.0
# 1108  Transferências a Instituições Privadas sem Fin...            0.0
# 1109  Transferências a Instituições Privadas sem Fin...            0.0
# 1110  Transferências a Instituições Privadas sem Fin...            0.0
# 1111  Transferências a Instituições Privadas sem Fin...            0.0
# 1112  Transferências a Instituições Privadas sem Fin...            0.0
# 1113  Transferências a Instituições Privadas sem Fin...            0.0
# 1114                            Reserva de Contingência            0.0
# 1115                            Reserva de Contingência            0.0
# 1116                            Reserva de Contingência            0.0
# 1117                            Reserva de Contingência            0.0
# 1118                            Reserva de Contingência            0.0
# 1119                            Reserva de Contingência            0.0
# 1120                            Reserva de Contingência            0.0
# 1121                            Reserva de Contingência            0.0
# 1122                            Reserva de Contingência            0.0
# 1123                            Reserva de Contingência            0.0
# 1124                            Reserva de Contingência            0.0
# 1125                            Reserva de Contingência            0.0
# 1126                            Reserva de Contingência            0.0
#
# [1127 rows x 8 columns]

# %% [markdown]
# ### 1.5 Consulta 3

# %%
# Liste todos os nomes dos órgãos e o valor das despesas totais no ano de 2018 para os
# mesmos, ordenando de forma decrescente pelo valor.

# %% [markdown]
# ### 1.6 Consulta 8

# %%
# Liste os nomes das subfunções das despesas públicas envolvidas para cada programa de
# governo. Sua consulta deve retornar o nome do programa de governo, a subfunção da
# despesa, a quantidade de entradas de despesas públicas e o valor total dessas despesas.

df = pd.read_sql_query("SELECT * "+
"FROM ORGAO ",
conn)
df
# Out:
#     COD_ORGAO                                     NOME_ORGAO  \
# 0       20000                       Presidência da República
# 1       22000  Ministério da Agricultura, Pecuária e Abastec
# 2       24000  Ministério da Ciência, Tecnologia, Inovações
# 3       25000                          Ministério da Fazenda
# 4       26000                         Ministério da Educação
# 5       30000      Ministério da Justiça e Segurança Pública
# 6       35000             Ministério das Relações Exteriores
# 7       36000                            Ministério da Saúde
# 8       39000  Ministério dos Transportes, Portos e Aviação
# 9       44000                    Ministério do Meio Ambiente
# 10      52000                           Ministério da Defesa
# 11      53000              Ministério da Integração Nacional
# 12      55000           Ministério do Desenvolvimento Social
# 13      81000                Ministério dos Direitos Humanos
#
#     QTD_ORGAOS_SUBORDINADOS
# 0                         2
# 1                         5
# 2                         4
# 3                         3
# 4                       104
# 5                         6
# 6                         1
# 7                         3
# 8                         2
# 9                         2
# 10                        4
# 11                        4
# 12                        2
# 13                        1

# %% [markdown]
# ## 2.1 Tradução de Comandos da Álgebra Relacional

# %%
conn.close()
